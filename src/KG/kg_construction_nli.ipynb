# %% [markdown]
# # Construct NLI-based knowledge graph of traits.
# KG tuple: <trait1, trait2, entailment_or_contradiction_score>

# %%
import networkx as nx

G1 = nx.read_gpickle("../data/traits_only_graph_cleaned2.pickle")

# %%
G1.edges(data=True)
# Out:
# EdgeDataView([('active', 'passive', {'weight': -1}), ('active', 'involved', {'weight': 1}), ('active', 'inactive', {'weight': -1}), ('considerate', 'inconsiderate', {'weight': -1}), ('considerate', 'thoughtful', {'weight': 1}), ('convivial', 'sociable', {'weight': 1}), ('diplomatic', 'tactful', {'weight': 1}), ('diplomatic', 'undiplomatic', {'weight': -1}), ('gregarious', 'ungregarious', {'weight': -1}), ('optimistic', 'positive', {'weight': 1}), ('optimistic', 'sanguine', {'weight': 1}), ('optimistic', 'cheerful', {'weight': 1}), ('optimistic', 'pessimistic', {'weight': -1}), ('mature', 'immature', {'weight': -1}), ('mature', 'adult', {'weight': 1}), ('mature', 'aged', {'weight': 1}), ('mature', 'big', {'weight': 1}), ('motivated', 'unmotivated', {'weight': -1}), ('sensible', 'wise', {'weight': 1}), ('sensible', 'thoughtful', {'weight': 1}), ('sensible', 'prudent', {'weight': 1}), ('sensible', 'reasonable', {'weight': 1}), ('sensible', 'logical', {'weight': 1}), ('sensible', 'intelligent', {'weight': 1}), ('sensible', 'advisable', {'weight': 1}), ('sensible', 'unreasonable', {'weight': -1}), ('brave', 'courageous', {'weight': 1}), ('brave', 'cowardly', {'weight': -1}), ('brave', 'fearless', {'weight': 1}), ('brave', 'bold', {'weight': 1}), ('chatty', 'talkative', {'weight': 1}), ('clever', 'smart', {'weight': 1}), ('clever', 'intelligent', {'weight': 1}), ('clever', 'ingenious', {'weight': 1}), ('clever', 'canny', {'weight': 1}), ('smart', 'stupid', {'weight': -1}), ('smart', 'intelligent', {'weight': 1}), ('smart', 'stylish', {'weight': 1}), ('smart', 'bright', {'weight': 1}), ('smart', 'fashionable', {'weight': 1}), ('cowardly', 'courageous', {'weight': -1}), ('cowardly', 'unmanly', {'weight': 1}), ('cowardly', 'timid', {'weight': 1}), ('friendly', 'amiable', {'weight': 1}), ('friendly', 'affable', {'weight': 1}), ('friendly', 'hostile', {'weight': -1}), ('friendly', 'favorable', {'weight': 1}), ('friendly', 'unfriendly', {'weight': -1}), ('funny', 'humorous', {'weight': 1}), ('funny', 'amusing', {'weight': 1}), ('funny', 'comical', {'weight': 1}), ('funny', 'strange', {'weight': 1}), ('funny', 'odd', {'weight': 1}), ('generous', 'big', {'weight': 1}), ('generous', 'benevolent', {'weight': 1}), ('generous', 'unselfish', {'weight': 1}), ('generous', 'large', {'weight': 1}), ('generous', 'liberal', {'weight': 1}), ('generous', 'stingy', {'weight': -1}), ('grumpy', 'grouchy', {'weight': 1}), ('grumpy', 'crabby', {'weight': 1}), ('honest', 'sincere', {'weight': 1}), ('honest', 'trustworthy', {'weight': 1}), ('honest', 'reliable', {'weight': 1}), ('honest', 'truthful', {'weight': 1}), ('honest', 'honorable', {'weight': 1}), ('honest', 'unpretentious', {'weight': 1}), ('honest', 'dependable', {'weight': 1}), ('honest', 'artless', {'weight': 1}), ('loud', 'big', {'weight': 1}), ('lucky', 'encouraging', {'weight': 1}), ('lucky', 'unlucky', {'weight': -1}), ('lucky', 'favorable', {'weight': 1}), ('lucky', 'fortunate', {'weight': 1}), ('nasty', 'unpleasant', {'weight': 1}), ('nasty', 'dirty', {'weight': 1}), ('nasty', 'awful', {'weight': 1}), ('nasty', 'hateful', {'weight': 1}), ('nasty', 'difficult', {'weight': 1}), ('neat', 'tidy', {'weight': 1}), ('nice', 'polite', {'weight': 1}), ('nice', 'courteous', {'weight': 1}), ('nice', 'decent', {'weight': 1}), ('nice', 'pleasant', {'weight': 1}), ('polite', 'courteous', {'weight': 1}), ('polite', 'rude', {'weight': -1}), ('polite', 'impolite', {'weight': -1}), ('popular', 'fashionable', {'weight': 1}), ('popular', 'hot', {'weight': 1}), ('popular', 'unpopular', {'weight': -1}), ('quiet', 'unpretentious', {'weight': 1}), ('quiet', 'calm', {'weight': 1}), ('quiet', 'tranquil', {'weight': 1}), ('quiet', 'uneventful', {'weight': 1}), ('quiet', 'unostentatious', {'weight': 1}), ('quiet', 'noisy', {'weight': -1}), ('rude', 'impolite', {'weight': 1}), ('rude', 'uncivil', {'weight': 1}), ('rude', 'crude', {'weight': 1}), ('rude', 'early', {'weight': 1}), ('selfish', 'unselfish', {'weight': -1}),  ...

# %%
import torch
from fairseq.data.data_utils import collate_tokens
from math import exp
import numpy as np

class RobertaMNLI:
    # todo: create similar wrapper classes for other NLI engines.
    # todo: create a wrapper superclass and subclass from there.
    
    def __init__(self, rel_path):
        self.output_map = {
            0: 'contradiction',
            1: 'neutral',
            2: 'entailment'
        }
        
        torch.hub.set_dir(rel_path)
        self.roberta = torch.hub.load('pytorch/fairseq', 'roberta.large.mnli')  # works
        self.roberta.cuda()
        self.roberta.eval()
        
    def predict_one(self, S1, S2, return_probs=False):
        batch = collate_tokens(
            [self.roberta.encode(S1, S2)], pad_idx=1
        )
        logprobs = self.roberta.predict('mnli', batch)
        classes_tsr = logprobs.argmax(dim=1)
        classes = classes_tsr.tolist()  
        
        if return_probs == True:
            logprobs_list=[logprob.item() for logprob in logprobs[0]]
            prob_list =  [pow(exp(1), logprob) for logprob in logprobs_list]
            return prob_list
        else:
            return classes[0]  # 0 is contradiction, 1 is neutral, 2 is entailment.

# %%
def entailment_score(predictor, S1, S2):
    """
    Returns entailment score of S1 and S2.
    We ignore the directionality of S1 and S2; we return the higher entailment score
    regardless of whether S1 entails S2 or S2 entails S1.
    
    :param predictor: wrapper class for NLI engine. See RobertaMNLI above.
    :param S1: String.
    :param S2: String.
    """
    probs1 = predictor.predict_one(S1, S2, return_probs=True)
    probs2 = predictor.predict_one(S2, S1, return_probs=True)
    e1 = probs1[2]  # index 2 is for entailment.
    e2 = probs2[2]
    return max(e1, e2)

def contradiction_score(predictor, S1, S2):
    """
    Returns contradiction score of S1 and S2.
    We ignore the directionality of S1 and S2; we return the higher score
    regardless of whether S1 contradicts S2, or S2 contradicts S1. 
    
    :param predictor: wrapper class for NLI engine. See RobertaMNLI above.
    :param S1: String.
    :param S2: String.
    """
    probs1 = predictor.predict_one(S1, S2, return_probs=True)
    probs2 = predictor.predict_one(S2, S1, return_probs=True)
    c1 = probs1[0]  # index 0 is for entailment.
    c2 = probs2[0]
    return max(c1, c2)

# %%
predictor = RobertaMNLI(rel_path="../../roberta/hub")
# Out:
# Using cache found in ../../roberta/hub\pytorch_fairseq_master

# %%
s1 = "brave"
s2 = "courageous"
entailment_score(predictor, s1, s2)
# Out:
# 0.9599203192182878

# %%
s1 = "brave"
s2 = "cowardly"
contradiction_score(predictor, s1, s2)
# Out:
# 0.9913602944411873

# %%
G2 = nx.Graph()

# make new knowledge graph where the edge weight is based on an NLI score.
for edge in G1.edges(data=True):
    if edge[2]['weight'] == 1:
        score = entailment_score(predictor, edge[0], edge[1])
        G2.add_edge(edge[0], edge[1], score=score)
    elif edge[2]['weight'] == -1:
        score = contradiction_score(predictor, edge[0], edge[1])
        G2.add_edge(edge[0], edge[1], score=-1*score) # -1 to indicate opposite polarity (antonymous relation)
    else:
        raise Exception("invalid weight value detected.")
G2.edges(data=True)
# Out:
# EdgeDataView([('active', 'passive', {'score': -0.9962928040560369}), ('active', 'involved', {'score': 0.8323226615075182}), ('active', 'inactive', {'score': -0.9951286145356494}), ('passive', 'inactive', {'score': 0.9475867187093776}), ('involved', 'interested', {'score': 0.8728021251452028}), ('involved', 'participating', {'score': 0.9517589468412195}), ('inactive', 'quiescent', {'score': 0.8819435041473466}), ('inactive', 'dull', {'score': 0.7789697707268533}), ('inactive', 'slow', {'score': 0.6159981150560486}), ('inactive', 'supine', {'score': 0.7104365261292587}), ('considerate', 'inconsiderate', {'score': -0.9963289099869019}), ('considerate', 'thoughtful', {'score': 0.9640939834721406}), ('inconsiderate', 'thoughtless', {'score': 0.82419437526209}), ('inconsiderate', 'careless', {'score': 0.8225489297020572}), ('thoughtful', 'sensible', {'score': 0.8281778560611142}), ('convivial', 'sociable', {'score': 0.9021289763443758}), ('sociable', 'agreeable', {'score': 0.8358482712908396}), ('sociable', 'congenial', {'score': 0.8801057542641602}), ('diplomatic', 'tactful', {'score': 0.7109912968917348}), ('diplomatic', 'undiplomatic', {'score': -0.9972101100864883}), ('gregarious', 'ungregarious', {'score': -0.9944763712177094}), ('optimistic', 'positive', {'score': 0.9677498921657827}), ('optimistic', 'sanguine', {'score': 0.924275908272098}), ('optimistic', 'cheerful', {'score': 0.9394636821944587}), ('optimistic', 'pessimistic', {'score': -0.996538445228127}), ('positive', 'enthusiastic', {'score': 0.9139203688698483}), ('positive', 'favorable', {'score': 0.9437445875174127}), ('positive', 'constructive', {'score': 0.9020373550817626}), ('positive', 'confident', {'score': 0.9060360307579671}), ('positive', 'convinced', {'score': 0.905087785819644}), ('positive', 'negative', {'score': -0.9943481075008335}), ('cheerful', 'upbeat', {'score': 0.9393205663005624}), ('cheerful', 'pollyannaish', {'score': 0.8109516824151083}), ('mature', 'immature', {'score': -0.9976096158322256}), ('mature', 'adult', {'score': 0.9294951591159784}), ('mature', 'aged', {'score': 0.9105244718575005}), ('mature', 'big', {'score': 0.6665835312865139}), ('immature', 'childish', {'score': 0.8916052505008967}), ('immature', 'ripe', {'score': -0.9706114693980034}), ('immature', 'early', {'score': 0.6466663738204976}), ('immature', 'naive', {'score': 0.8619217384112619}), ('immature', 'young', {'score': 0.9045148296884026}), ('immature', 'vulnerable', {'score': 0.5284562757203515}), ('immature', 'little', {'score': 0.8920743148594267}), ('immature', 'small', {'score': 0.8074046039208286}), ('adult', 'juvenile', {'score': -0.9956811024933967}), ('big', 'generous', {'score': 0.5246429447323201}), ('big', 'loud', {'score': 0.6732174709869303}), ('big', 'large', {'score': 0.9435614502066831}), ('big', 'great', {'score': 0.6755453146794339}), ('big', 'sizeable', {'score': 0.7465301324926633}), ('big', 'handsome', {'score': 0.5501194560270831}), ('big', 'bountiful', {'score': 0.8684170212140624}), ('big', 'ample', {'score': 0.34454172603319655}), ('big', 'grownup', {'score': 0.9029923074284254}), ('big', 'bounteous', {'score': 0.8601700051344895}), ('big', 'magnanimous', {'score': 0.6615416213096017}), ('big', 'giving', {'score': 0.26842329734104914}), ('big', 'openhanded', {'score': 0.23383586343827492}), ('big', 'heroic', {'score': 0.5111804868297071}), ('big', 'bighearted', {'score': 0.8469766574645521}), ('big', 'liberal', {'score': 0.22474833594048793}), ('big', 'little', {'score': -0.9940693510115695}), ('big', 'small', {'score': -0.9965275159971728}), ('motivated', 'unmotivated', {'score': -0.9941854900504913}), ('sensible', 'wise', {'score': 0.8661220471390246}), ('sensible', 'prudent', {'score': 0.9359168628802425}), ('sensible', 'reasonable', {'score': 0.9438264933441008}), ('sensible', 'logical', {'score': 0.9562096329921865}), ('sensible', 'intelligent', {'score': 0.8933594443083296}), ('sensible', 'advisable', {'score': 0.7685937190157792}), ('sensibl ...

# %%
len(G2.edges)
# Out:
# 585

# %%
len(G1.edges)
# Out:
# 585

# %%
path = input("enter path to save pickled graph:\n")
nx.write_gpickle(G2, path)
# Out:
# enter path to save pickled graph:
#  ../data/traits_only_graph_nli.pickle
